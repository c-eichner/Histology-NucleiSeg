# %% [markdown]
# # Data Inspection
#
# This notebook aims at having a first look at the data, try to understand the datastructure, and identify potential biases in the provided dataset.

# %%
# Libraries imported in alphabetical order

# %matplotlib notebook

from pathlib import Path # Loop over folder structures 
from PIL import Image # Load image data 
from skimage.measure import label # Find clusters in the label data
from tqdm.notebook import tqdm # Access to a progressbar

# Import standard data science libraries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# First, rename folder to remove spaces
# !mv -f data/mask\ binary/ data/mask_binary/
# Out:
# mv: cannot stat 'data/mask binary/': No such file or directory

# %%
# Set root paths of provided image data 
root_path = Path("data/tissue_images/")

# %% [markdown]
# ### Helper function to handle file paths of image and label data
#
# Dealing with multple path variables can be confusing. Therefore, I generate a help function to convert img paths in label paths

# %%
def change_img_to_label_path(path, fol_pre = 'tissue_images', fol_post = 'mask_binary', suf_pre = 'tif', suf_post = 'png'):
    """
    Helper function to rename image paths to match label paths
    """
    
    parts = list(path.parts)  # get all directories within the path
    parts[parts.index(fol_pre)] = fol_post  # Replace tissue_images with mask_binary
    
    # Get Filename of Path by string splitting the last entry 
    filename = parts[-1].split(".")
    # Replace Filename Suffix
    filename[filename.index(suf_pre)] = suf_post
    
    #Put Together all parts to create the list new_path, pointing to the label directory
    new_path = parts[:-1] + [str(filename[0]) + "." + str(filename[1])]

    return Path(*new_path)  # Combine list back into a Path object

# %% [markdown]
# For future use, this function will be stored for future use in functions.py

# %% [markdown]
# ### Load and display an exemplary dataset

# %% [markdown]
# Generate and check img and label path variables

# %%
sample_path = list(root_path.glob("Human_*"))[0]  # Choose the first entry as an exemplary sample 
sample_path_label = change_img_to_label_path(sample_path) # Convert path to label path

print(sample_path)
print(sample_path_label)

# %% [markdown]
# Look at image and label dimensions

# %%
# Load the image files with PIL and convert the to numpy arrays
img = np.asarray(Image.open(sample_path))
mask = np.asarray(Image.open(sample_path_label))

print('Image Size = {} x {}'.format(img.shape[0], img.shape[1]))
print('Label Size = {} x {}'.format(mask.shape[0], mask.shape[1]))
# Out:
# Image Size = 512 x 512
# Label Size = 512 x 512

# %% [markdown]
# Plot the loaded image data, overlayed with nuclei labels

# %%
# Extract individual masks using 'labels' from scikit-image
# I chose connectivity = 1 to count only directly connected masks
labeled_masks = label(mask, connectivity=1, background = 0)

# scikit image label marks every nonzero cluster with a counting number. 
# Therefore, to identify the number of nuclei, the amount of unique elements in 'labeled_masks' needs to be counted   

# Generate Matplotlib Figure 
plt.figure()
plt.title('Example Image Data with {} Identified Nuclei'.format(len(np.unique(labeled_masks[labeled_masks > 0]))))
plt.imshow(img)
plt.contour(mask)
plt.axis('off')
# Out:
# <img src="data:image/png;base64,..." width="640">
# (-0.5, 511.5, 511.5, -0.5)

# %% [markdown]
# Loop over all images, check if dimensions match, and check the tissue types

# %%
all_files = list(root_path.glob("*tif"))  # Get paths to all subjects
print('Total {} images to check'.format(len(all_files)))
# Out:
# Total 28 images to check

# %% [markdown]
# Loop over all subjects and save image metadata in pandas dataframe

# %%
df = pd.DataFrame(columns=['Path', 
                           'Tissue', 
                           'Img Width', 
                           'Img Height', 
                           'Mask Width', 
                           'Mask Height', 
                           'Size Conflict',
                           'Img Max Val'])

# Loop over all img files
for counter, path_to_img in enumerate(tqdm(all_files)):

    # Get mask path from img path
    path_to_label = change_img_to_label_path(path_to_img)
    
    # Load the data
    img = np.asarray(Image.open(path_to_img))
    mask = np.asarray(Image.open(path_to_label))
    
    # Extract width and heigth of img and label
    ImgWidth =  img.shape[0]
    ImgHeight =  img.shape[1]
    MaskWidth =  mask.shape[0]
    MaskHeight = mask.shape[1]
    
    # Check if img and label sizes match
    if img.shape[:2] == mask.shape:
        SizeConflict = False
    else:
        SizeConflict = True
        
    # Check the filename to identify tissue type
    filename = path_to_img.name
    tissue_type = filename.split('_')[1]
    
    # Put all subject specific metadata in dict structure and append to dataframe
    df2 = {'Path':path_to_label, 
           'Tissue':tissue_type, 
           'Img Width':ImgWidth, 
           'Img Height':ImgHeight, 
           'Mask Width':MaskWidth, 
           'Mask Height':MaskHeight,
           'Size Conflict':SizeConflict,
           'Img Max Val':img.max()}

    df = df.append(df2, ignore_index = True)
# Out:
#   0%|          | 0/28 [00:00<?, ?it/s]

# %% [markdown]
# Check Dataframe structure

# %%
df
# Out:
#                                           Path        Tissue Img Width  \
# 0   data/mask_binary/Human_AdrenalGland_01.png  AdrenalGland       512
# 1    data/mask_binary/Human_Mediastinum_03.png   Mediastinum       512
# 2    data/mask_binary/Human_Mediastinum_02.png   Mediastinum       512
# 3   data/mask_binary/Human_ThyroidGland_03.png  ThyroidGland       512
# 4     data/mask_binary/Human_LymphNodes_01.png    LymphNodes       512
# 5         data/mask_binary/Human_Thymus_02.png        Thymus       512
# 6         data/mask_binary/Human_Thymus_03.png        Thymus       512
# 7           data/mask_binary/Human_Skin_03.png          Skin       512
# 8       data/mask_binary/Human_Pancreas_01.png      Pancreas       512
# 9           data/mask_binary/Human_Skin_02.png          Skin       512
# 10    data/mask_binary/Human_LymphNodes_02.png    LymphNodes       512
# 11        data/mask_binary/Human_Testes_03.png        Testes       512
# 12        data/mask_binary/Human_Testes_02.png        Testes       512
# 13          data/mask_binary/Human_Skin_01.png          Skin       512
# 14        data/mask_binary/Human_Pleura_01.png        Pleura       512
# 15        data/mask_binary/Human_Larynx_01.png        Larynx       512
# 16      data/mask_binary/Human_Pancreas_03.png      Pancreas       512
# 17        data/mask_binary/Human_Larynx_02.png        Larynx       512
# 18      data/mask_binary/Human_Pancreas_02.png      Pancreas       512
# 19  data/mask_binary/Human_ThyroidGland_02.png  ThyroidGland       512
# 20        data/mask_binary/Human_Thymus_01.png        Thymus       512
# 21        data/mask_binary/Human_Pleura_03.png        Pleura       512
# 22        data/mask_binary/Human_Larynx_03.png        Larynx       512
# 23  data/mask_binary/Human_AdrenalGland_02.png  AdrenalGland       512
# 24        data/mask_binary/Human_Pleura_02.png        Pleura       512
# 25        data/mask_binary/Human_Testes_01.png        Testes       512
# 26  data/mask_binary/Human_AdrenalGland_03.png  AdrenalGland       512
# 27   data/mask_binary/Human_Mediastinum_01.png   Mediastinum       512
#
#    Img Height Mask Width Mask Height Size Conflict Img Max Val
# 0         512        512         512         False         255
# 1         512        512         512         False         255
# 2         512        512         512         False         255
# 3         512        512         512         False         255
# 4         512        512         512         False         255
# 5         512        512         512         False         255
# 6         512        512         512         False         255
# 7         512        512         512         False         255
# 8         512        512         512         False         255
# 9         512        512         512         False         255
# 10        512        512         512         False         253
# 11        512        512         512         False         255
# 12        512        512         512         False         255
# 13        512        512         512         False         255
# 14        512        512         512         False         250
# 15        512        512         512         False         255
# 16        512        512         512         False         255
# 17        512        512         512         False         255
# 18        512        512         512         False         255
# 19        512        512         512         False         255
# 20        512        512         512         False         255
# 21        512        512         512         False         255
# 22        512        512         512         False         255
# 23        512        512         512         False         255
# 24        512        512         512         False         255
# 25        512        512         512         False         255
# 26        512        512         512         False         255
# 27        512        512         512         False         255

# %% [markdown]
# No size conflicts identified!

# %% [markdown]
# Finally, check and count the provided tissue types. This way, we can identify potential sampling biases that would need to be counteracted by random weighted sampling during the training.

# %%
print("Tissue Types: {}".format(df['Tissue'].unique()))
# Out:
# Tissue Types: ['AdrenalGland' 'Mediastinum' 'ThyroidGland' 'LymphNodes' 'Thymus' 'Skin'
#  'Pancreas' 'Testes' 'Pleura' 'Larynx']

# %%
df['Tissue'].value_counts()
# Out:
# Pleura          3
# Pancreas        3
# Skin            3
# Thymus          3
# AdrenalGland    3
# Larynx          3
# Testes          3
# Mediastinum     3
# ThyroidGland    2
# LymphNodes      2
# Name: Tissue, dtype: int64

# %% [markdown]
# It seems that there is no strong oversampling of one specific tissue type. Hence, we will not use weighted data loaders.

# %%
print(img.shape)
img.mean(axis = (0,1))
img.std(axis = (0,1))
# Out:
# (512, 512, 3)
# array([50.20419395, 43.08574425, 37.89285443])
